# %%
import yaml
import tiktoken

from langchain import OpenAI, VectorDBQA, LLMChain
from langchain.prompts import PromptTemplate

from pdf_loaders import PdfToTextLoader
from dataset_vectorizers import DatasetVectorizer

with open("config.yml", "r") as f:
    config = yaml.safe_load(f)

OPENAI_API_KEY = config['OPENAI_KEY']

# %% [markdown]
# ## Loading data from PDF

# %%
# data taken from https://www.freelancersunion.org/insurance/health/bronze-plans-nyc/
PDFS, NAMES, TXTS  = [
    './data/hyosung.pdf',
], [
    'HyosungManual',
], []

# %%
for pdf_path in PDFS:
    txt_path = pdf_path.replace(".pdf", ".txt")
    pdf_loader = PdfToTextLoader(pdf_path, txt_path)
    text = pdf_loader.load_pdf()
    TXTS.append(txt_path)

# %% [markdown]
# ## Vectorizing dataset

# %%
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 500

# %%
dataset_vectorizer = DatasetVectorizer()
documents_1, texts_1, docsearch_1 = dataset_vectorizer.vectorize([TXTS[0]], chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP, openai_key=OPENAI_API_KEY)

# %% [markdown]
# ## Asking questions

# %%
QUESTIONS = [
    "When i click on the started, i hear a sound of a spark but the moto doesn't start, what is the problem ?"
]

# %%
result = docsearch_1._collection.query(query_texts=QUESTIONS)
pprint(result)
# Out:
# {'distances': [[0.3228591978549957,
#                 0.3299810290336609,
#                 0.33232802152633667,
#                 0.3430679440498352,
#                 0.34917712211608887,
#                 0.36154690384864807,
#                 0.362285852432251,
#                 0.36243781447410583,
#                 0.36305689811706543,
#                 0.36877235770225525],
#                [0.32797783613204956,
#                 0.33691608905792236,
#                 0.3397848904132843,
#                 0.3491109013557434,
#                 0.3665180206298828,
#                 0.36716538667678833,
#                 0.38054680824279785,
#                 0.38070181012153625,
#                 0.3847043514251709,
#                 0.38479456305503845],
#                [0.2907882332801819,
#                 0.3186514675617218,
#                 0.32647505402565,
#                 0.32844775915145874,
#                 0.3318900167942047,
#                 0.3394894599914551,
#                 0.3545929789543152,
#                 0.3586655557155609,
#                 0.3610798120498657,
#                 0.36969926953315735]],
#  'documents': [['The memorized malfunction code is displayed on the odometer '
#                 'screen B or by blinks signal of the engine warning \n'
#                 'lamp “ ” A. \n'
#                 'Malfunction means that the ECU does not receive signal from '
#                 'the devices or fault signal received. \n'
#                 'These affected devices are indicated in the code form on the '
#                 'odometer screen B or displayed by blinks signal \n'
#                 'of the engine warning lamp “ ” A. \n'
#                 'A. ODOMETER SCREEN \n'
#                 'To confirm the memorized malfunction code through the '
#                 'odometer screen B. \n'
#                 '1. Remove the left side cover. \n'
#                 '2. Connect the special tool to the dealer mode coupler at the '
#                 'wiri ng harness, and the ignition switch is set to the “ON” '
#                 'position.  \n'
#                 ' Mode select switch: 09900-27000  \n'
#                 '3. Turn the special tool’s switch to the “ON” position. \n'
#                 '4. Press the select switch  C (in the odometer mode) for 5 '
#                 'seconds until  the odometer screen B is displayed \n'
#                 '[the malfunction code mode] after displaying the “SEND” '
#                 'letters for a second. \n'
#                 ' \n'
#                 'N O T E',
#                 '3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS \n'
#                 'P0031  [         0                  0          3    '
#                 '1            0                0            3    1   ]  \n'
#                 'NO.1 O₂S heater Circuit Low Voltage For NO.1 cylinder \n'
#                 'P0032    \n'
#                 '[         0                  0           3     2            '
#                 '0                 0           3       ]  \n'
#                 'NO.1 O₂S heater Circuit High Voltage  For NO.1 cylinder  \n'
#                 'P0037    \n'
#                 '[         0                  0           3          '
#                 '7               0                 0          ]  \n'
#                 'NO.2 O2Sheater Ci rcuit Low Voltage For NO.2 cylinder \n'
#                 'P0038',
#                 'Ecu Fault  \n'
#                 'P0650   \n'
#                 '[         0              6          5             '
#                 '0                  0                    ]  \n'
#                 'Engine warning lamp Circuit Malfunction  \n'
#                 'P0850   \n'
#                 '[         0               8             5            '
#                 '0                 0                 ]  \n'
#                 'GP or clutch lever swit ch Circuit Malfunction  \n'
#                 ' \n'
#                 '    \n'
#                 ' \n'
#                 '   ※A CODE ： For Odometer screen indication \n'
#                 ' \n'
#                 '※B CODE ： For Engine warning lamp indication \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-18  \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARNING LAMP INDICATION  \n'
#                 'In the engine warning lamp“ ”A the malfunction code is '
#                 'displayed by blin king the signal in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 'B. ODOMETER SCREENINDICATION  \n'
#                 'In the odometer screen B, the malfunction code is indicated '
#                 'in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-19 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'EI SYSTEM TROUBLESHOOTING \n'
#                 'CUSTOMER COMPLAINT ANALYSIS \n'
#                 'Record details of the problem (failure, complaint) and how it '
#                 'occurred as described by the customer.',
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS \n'
#                 'P0171   \n'
#                 '[         0         1         7       1          0           '
#                 '1        7        1                 ]  \n'
#                 'Injection Fuel Shortage  \n'
#                 'P0172   \n'
#                 '[         0         1         7        2          '
#                 '0            1        7        2                 ]  \n'
#                 'Injection Fuel Excess  \n'
#                 'P0201   \n'
#                 '[         0          2           0          1          '
#                 '0           2          0           1       ]  \n'
#                 'NO.1 Fuel injector Circuit Malfunction For NO.1 cylinder \n'
#                 'P0202   \n'
#                 '[         0          2           0           2           '
#                 '0           2           0           2   ]  \n'
#                 'NO.2 Fuel injector Circuit Malfunction For NO.2 cylinder \n'
#                 'P0230   \n'
#                 '[         0          2      3           0           2      '
#                 '3            0          2     3       ]  \n'
#                 'Fuel pump relay Circuit Low Voltage or \n'
#                 'Open  \n'
#                 'P0232   \n'
#                 '[         0          2      3     2           0           '
#                 '2     3            0           2     3  ]  \n'
#                 'Fuel pump relay Circuit High Voltage  \n'
#                 'P0336',
#                 'P0601 ECU Fault When ML on The ECU will check malfunction '
#                 'code, if there’s \n'
#                 'ECU error the code P0601 is indicated. The fuel injection '
#                 'will be cut off Accordingly \n'
#                 'ECU \n'
#                 'P0650  \n'
#                 'Engine warning \n'
#                 'lamp Circuit Malfunction After engine running, if “FI” check '
#                 'lamp signal open or is \n'
#                 'happened the high / ground short fault for 1 second by 40 \n'
#                 'times in 80 times test cycle, the code 0650 is indicated. \n'
#                 '“FI” check lamp, wiring / coupler connection. \n'
#                 'P0850  \n'
#                 ' \n'
#                 'GP or Clutch lever Switch \n'
#                 'Circuit Malfunction If gear position or clutch lever switch '
#                 'signal feedback is not \n'
#                 'active in continuous by 20 times in fully power down cycles, '
#                 'the\n'
#                 'code 0850 is indicated. \n'
#                 '(Fully power down cycle : Ignition switch “ON” “OFF” '
#                 'position)\n'
#                 'Gear position or clutch lever switch, wiring / coupler '
#                 'connection, \n'
#                 'gearshift cam etc. \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-28  \n'
#                 ' \n'
#                 '“P0031”, “P0032”, “P0037” or “P0038” \n'
#                 'OXYGEN SENSOR HEATER  CIRCUIT MALFUNCTION \n'
#                 ' & “0131”, “0132”, “0137” or “0138” \n'
#                 'OXYGEN SENSOR CIRCUIT MALFUNCTION',
#                 'SELF-DIAGNOSTIC PROCEDURES \n'
#                 'Don’t disconnect couplers from ECU, battery cable fr om '
#                 'battery, ECU ground wire harness from engine or \n'
#                 'main fuse before confirming malfunction code (self-di '
#                 'agnostic trouble code) stored in memory. the memorized \n'
#                 'malfunction code is displayed in the code form on the '
#                 'odometer screen B or by blinks signal of the engine \n'
#                 'warning lamp “  ” A. \n'
#                 ' \n'
#                 ' To check malfunction code, read SELF-DIAGNOSIS FUNC TION '
#                 '“DEALER MODE” (Refer to page [4-11~ 18]) \n'
#                 'carefully to have good understanding as to what  functions '
#                 'are available and how to use it. \n'
#                 ' \n'
#                 'Be sure to read “PRECAUTIONS for Electrical Circui t Service” '
#                 '(Refer to page [4-1]) before inspection and \n'
#                 'observe what is written there. \n'
#                 '   \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-22  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'A. ODOMETER SCREEN INDICATION \n'
#                 'Refer to page [4-11] \n'
#                 ' \n'
#                 ' \n'
#                 'B. ENGINE WARNING LAMP INDICATION \n'
#                 'Refer to page [4-13] \n'
#                 '      \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '   \n'
#                 ' \n'
#                 '    H\n'
#                 '    P  USKEY\n'
#                 ' \n'
#                 ' \n'
#                 '4-23 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'SELF-DIAGNOSIS RESET \n'
#                 'PROCEDURE',
#                 '“P0031”,“P0032”,“P0037”or“P0038”OXYG EN SENSOR HEATER '
#                 'CIRCUIT   \n'
#                 'MALFUNCTION &“P0131”,“P0132”,“P0137”or“P0138”  \n'
#                 'OXYGEN SENSOR CIRCUIT MALFUNCTION …………………………………………………… 4-28\n'
#                 '“P0107”or“P0108”IAP&T(Pressure functi on)SENSOR CIRCUIT '
#                 'MALFUNCTION ………… 4-30\n'
#                 '“P0112”or“P0113”IAP&T(Temperature func tion) SENSOR CIRCUIT '
#                 'MALFUNCTION …… 4-32\n'
#                 '“P0117”or“P0118”WTSENSOR CIRCUIT MALFUNCTION …………………………………… '
#                 '4-34\n'
#                 '“P0122”or“P0123”TPSENSOR CIRCUIT MALFUNCTION ……………………………………… '
#                 '4-36\n'
#                 '“P0171” or“P0172” FUEL INJECTION CIRCUIT MALFUNCTION '
#                 '…………………………… 4-39\n'
#                 '“P0201”or“P0202”FUELINJECTOR CIRCUIT MALFUNCTION ……………………………… '
#                 '4-40\n'
#                 '“P0230”or“P0232”FUEL PUMP RELAY CIRCUIT MALFUNCTION '
#                 '…………………………… 4-42\n'
#                 '“P0336”or“P0337” PICK-UP COILCIRCUIT MALFUNCTION '
#                 '………………………………… 4-43\n'
#                 '“P0351”or“P0352”IGNITION COIL MALFUNCTION …………………………………………… '
#                 '4-45\n'
#                 '“P0500” SPEEDO SENSOR MALFUNCTION …………………………………………………… 4-46\n'
#                 '“P0505” ISC SOLENOID RANGE ABNORMAL …………………………………………………… '
#                 '4-47\n'
#                 '“P0562” or “P0563” BATTERY VOLTAG EMALFUNCTION …………………………………… '
#                 '4-48',
#                 '“P0201”or“P0202”FUELINJECTOR CIRCUIT MALFUNCTION ……………………………… '
#                 '4-40\n'
#                 '“P0230”or“P0232”FUEL PUMP RELAY CIRCUIT MALFUNCTION '
#                 '…………………………… 4-42\n'
#                 '“P0336”or“P0337” PICK-UP COILCIRCUIT MALFUNCTION '
#                 '………………………………… 4-43\n'
#                 '“P0351”or“P0352”IGNITION COIL MALFUNCTION …………………………………………… '
#                 '4-45\n'
#                 '“P0500” SPEEDO SENSOR MALFUNCTION …………………………………………………… 4-46\n'
#                 '“P0505” ISC SOLENOID RANGE ABNORMAL …………………………………………………… '
#                 '4-47\n'
#                 '“P0562” or “P0563” BATTERY VOLTAG EMALFUNCTION …………………………………… '
#                 '4-48\n'
#                 '“P0601” ECU FAULT MALFUNCTION ……………………………………………………………… 4-49\n'
#                 '“P0650”ENGINE WARNING LAMP CIRCUIT MALFUNCTION ………………………………… '
#                 '4-50\n'
#                 '“P0850”GPorCLUTCH LEVER SWITCH CIRCUIT MALFUNCTION '
#                 '…………………………  4-51\n'
#                 'SENSORS …………………………………………………………………………………………………… 4-53\n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-1 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'PRECAUTIONS IN SERVICING \n'
#                 'When handling the component parts or servicing the \n'
#                 'EI system, observe the following points for the safety of the '
#                 'system. \n'
#                 '⊙ELECTRICAL PARTS  \n'
#                 '▣ CONNECTOR / COUPLER  \n'
#                 '● When connecting a connector, be sure to push it in',
#                 '[         0             5              0             '
#                 '5             0              5          ]  \n'
#                 'ISC Error  \n'
#                 'P0562   \n'
#                 '[         0             5          6        2            '
#                 '0             5         6       2    ]  \n'
#                 'Battery Voltage Low  \n'
#                 'P0563   \n'
#                 '[         0             5          6        3            '
#                 '0              5         6          ]  \n'
#                 'Battery Voltage High  \n'
#                 'P0601   \n'
#                 '[         0              6              0         '
#                 '1            0             6              ]  \n'
#                 'Ecu Fault  \n'
#                 'P0650   \n'
#                 '[         0              6          5             '
#                 '0                  0                    ]  \n'
#                 'Engine warning lamp Circuit Malfunction  \n'
#                 'P0850   \n'
#                 '[         0               8             5            '
#                 '0                 0                 ]  \n'
#                 'GP or clutch lever swit ch Circuit Malfunction  \n'
#                 ' \n'
#                 '    \n'
#                 ' \n'
#                 '   ※A CODE ： For Odometer screen indication \n'
#                 ' \n'
#                 '※B CODE ： For Engine warning lamp indication \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-18  \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARNING LAMP INDICATION',
#                 'B. ENGINE WARNING LAMP \n'
#                 'To confirm the memorized malfunction code through the engine '
#                 'warning lamp “ ”  A: \n'
#                 '1. Turn the ignition switch alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by three times. \n'
#                 ' \n'
#                 'Take special care when operating above procedure. \n'
#                 'If the ignition switch is turned alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by five times, the ECU is '
#                 'initialized.\n'
#                 ' \n'
#                 '2. The memorized malfunction code is displayed with blinks '
#                 'signal of the engine warning lamp “  ” A. \n'
#                 '3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS'],
#                ['3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS \n'
#                 'P0031  [         0                  0          3    '
#                 '1            0                0            3    1   ]  \n'
#                 'NO.1 O₂S heater Circuit Low Voltage For NO.1 cylinder \n'
#                 'P0032    \n'
#                 '[         0                  0           3     2            '
#                 '0                 0           3       ]  \n'
#                 'NO.1 O₂S heater Circuit High Voltage  For NO.1 cylinder  \n'
#                 'P0037    \n'
#                 '[         0                  0           3          '
#                 '7               0                 0          ]  \n'
#                 'NO.2 O2Sheater Ci rcuit Low Voltage For NO.2 cylinder \n'
#                 'P0038',
#                 'Ecu Fault  \n'
#                 'P0650   \n'
#                 '[         0              6          5             '
#                 '0                  0                    ]  \n'
#                 'Engine warning lamp Circuit Malfunction  \n'
#                 'P0850   \n'
#                 '[         0               8             5            '
#                 '0                 0                 ]  \n'
#                 'GP or clutch lever swit ch Circuit Malfunction  \n'
#                 ' \n'
#                 '    \n'
#                 ' \n'
#                 '   ※A CODE ： For Odometer screen indication \n'
#                 ' \n'
#                 '※B CODE ： For Engine warning lamp indication \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-18  \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARNING LAMP INDICATION  \n'
#                 'In the engine warning lamp“ ”A the malfunction code is '
#                 'displayed by blin king the signal in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 'B. ODOMETER SCREENINDICATION  \n'
#                 'In the odometer screen B, the malfunction code is indicated '
#                 'in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-19 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'EI SYSTEM TROUBLESHOOTING \n'
#                 'CUSTOMER COMPLAINT ANALYSIS \n'
#                 'Record details of the problem (failure, complaint) and how it '
#                 'occurred as described by the customer.',
#                 'The memorized malfunction code is displayed on the odometer '
#                 'screen B or by blinks signal of the engine warning \n'
#                 'lamp “ ” A. \n'
#                 'Malfunction means that the ECU does not receive signal from '
#                 'the devices or fault signal received. \n'
#                 'These affected devices are indicated in the code form on the '
#                 'odometer screen B or displayed by blinks signal \n'
#                 'of the engine warning lamp “ ” A. \n'
#                 'A. ODOMETER SCREEN \n'
#                 'To confirm the memorized malfunction code through the '
#                 'odometer screen B. \n'
#                 '1. Remove the left side cover. \n'
#                 '2. Connect the special tool to the dealer mode coupler at the '
#                 'wiri ng harness, and the ignition switch is set to the “ON” '
#                 'position.  \n'
#                 ' Mode select switch: 09900-27000  \n'
#                 '3. Turn the special tool’s switch to the “ON” position. \n'
#                 '4. Press the select switch  C (in the odometer mode) for 5 '
#                 'seconds until  the odometer screen B is displayed \n'
#                 '[the malfunction code mode] after displaying the “SEND” '
#                 'letters for a second. \n'
#                 ' \n'
#                 'N O T E',
#                 'A. ENGINE WARNING LAMP INDICATION  \n'
#                 'In the engine warning lamp“ ”A the malfunction code is '
#                 'displayed by blin king the signal in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 'B. ODOMETER SCREENINDICATION  \n'
#                 'In the odometer screen B, the malfunction code is indicated '
#                 'in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-19 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'EI SYSTEM TROUBLESHOOTING \n'
#                 'CUSTOMER COMPLAINT ANALYSIS \n'
#                 'Record details of the problem (failure, complaint) and how it '
#                 'occurred as described by the customer. \n'
#                 'For this purpose, use of such an inspec tion form will '
#                 'facilitate co llecting information to the point required for '
#                 'proper \n'
#                 'analysis and diagnosis. \n'
#                 ' \n'
#                 '▣ EXAMPLE : CUSTOMER PRO BLEM INSPECTION FORM \n'
#                 'User name : Model : VIN : \n'
#                 'Date of issue : Date Reg. : Date of problem : Mileage : \n'
#                 ' \n'
#                 ' \n'
#                 'Engine warning lamp 口  \n'
#                 'Always ON 口 Sometimes ON 口 \n'
#                 'Always \n'
#                 'OFF 口  \n'
#                 'Good   \n'
#                 'condition \n'
#                 'Malfunction display / code \n'
#                 '(odometer screen) or Blinks signal ( Engine warning lamp)  \n'
#                 '口  \n'
#                 ' \n'
#                 'No code  \n'
#                 '口 \n'
#                 ' \n'
#                 'Malfunction code ( \n'
#                 ' \n'
#                 ')',
#                 'P0601 ECU Fault When ML on The ECU will check malfunction '
#                 'code, if there’s \n'
#                 'ECU error the code P0601 is indicated. The fuel injection '
#                 'will be cut off Accordingly \n'
#                 'ECU \n'
#                 'P0650  \n'
#                 'Engine warning \n'
#                 'lamp Circuit Malfunction After engine running, if “FI” check '
#                 'lamp signal open or is \n'
#                 'happened the high / ground short fault for 1 second by 40 \n'
#                 'times in 80 times test cycle, the code 0650 is indicated. \n'
#                 '“FI” check lamp, wiring / coupler connection. \n'
#                 'P0850  \n'
#                 ' \n'
#                 'GP or Clutch lever Switch \n'
#                 'Circuit Malfunction If gear position or clutch lever switch '
#                 'signal feedback is not \n'
#                 'active in continuous by 20 times in fully power down cycles, '
#                 'the\n'
#                 'code 0850 is indicated. \n'
#                 '(Fully power down cycle : Ignition switch “ON” “OFF” '
#                 'position)\n'
#                 'Gear position or clutch lever switch, wiring / coupler '
#                 'connection, \n'
#                 'gearshift cam etc. \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-28  \n'
#                 ' \n'
#                 '“P0031”, “P0032”, “P0037” or “P0038” \n'
#                 'OXYGEN SENSOR HEATER  CIRCUIT MALFUNCTION \n'
#                 ' & “0131”, “0132”, “0137” or “0138” \n'
#                 'OXYGEN SENSOR CIRCUIT MALFUNCTION',
#                 'B. ENGINE WARNING LAMP \n'
#                 'To confirm the memorized malfunction code through the engine '
#                 'warning lamp “ ”  A: \n'
#                 '1. Turn the ignition switch alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by three times. \n'
#                 ' \n'
#                 'Take special care when operating above procedure. \n'
#                 'If the ignition switch is turned alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by five times, the ECU is '
#                 'initialized.\n'
#                 ' \n'
#                 '2. The memorized malfunction code is displayed with blinks '
#                 'signal of the engine warning lamp “  ” A. \n'
#                 '3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS',
#                 'MALFUNCTION \n'
#                 'CODE DETECTED ITEM DETECTED FAILURE CONDITION \n'
#                 'CHECK FOR \n'
#                 ' \n'
#                 ' \n'
#                 'P0500 \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 '   \n'
#                 'Speed sensor \n'
#                 'Malfunction \n'
#                 ' \n'
#                 ' Motorcycle speed ＜10km/h \n'
#                 'Water temperature ＜20℃ \n'
#                 'IAP&TS pressure ＞40kpa \n'
#                 '20%＜TPS open angle ＜100% \n'
#                 '2,000rpm ＜Engine speed ＜6,000rpm \n'
#                 'If the above conditions are maintained for 32.5sec.and more,\n'
#                 'The code P0500 is indicated \n'
#                 'Speedo sensor, wiring/coupler connection to ECU \n'
#                 ' \n'
#                 'P0505  \n'
#                 ' \n'
#                 'ISC Error After engine running, if idle speed is different to '
#                 '500 rpm from \n'
#                 'the specified range in 25 seconds test cycle, the code 0505 '
#                 'is \n'
#                 'indicated. \n'
#                 'Idle speed control solenoid, wiring / coupler connection. \n'
#                 ' \n'
#                 'P0562  \n'
#                 ' \n'
#                 '  \n'
#                 'Battery \n'
#                 'Voltage   \n'
#                 ' \n'
#                 'Low The battery voltage should be the \n'
#                 'following 9 V ≤Battery voltage \n'
#                 'Without the above range for3.125sec.andmore,0562 is '
#                 'indicated.\n'
#                 'Battery,  wiring / coupler connection to ECU. \n'
#                 ' \n'
#                 ' \n'
#                 'P0563  \n'
#                 ' \n'
#                 'High The battery voltage should be the \n'
#                 'following. Battery voltage ≤16V \n'
#                 'Without the above range for 3.12 5 sec.andmore,0563 is '
#                 'indicated.',
#                 'EI SYSTEM DIAGNOSIS 4-12  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '             \n'
#                 '❖ Confirm the malfunction code after turning the ignition '
#                 'switch “ON” position and starting the engine \n'
#                 'separately. \n'
#                 '❖ The dealer mode coupler of the wiring harness is located '
#                 'Left side cover. \n'
#                 '  \n'
#                 'CLASSIFICATION MALFUNCTI\n'
#                 'ON ODOMETERSCR\n'
#                 'EEN \n'
#                 'INDICATION B ENGINE \n'
#                 'WARNING LAMP \n'
#                 'INDICATION A INDICATION \n'
#                 'MODE \n'
#                 ' \n'
#                 ' \n'
#                 'IGNITION \n'
#                 'SWITCH \n'
#                 '“ON” \n'
#                 'POSTION   \n'
#                 '“NO”  \n'
#                 'NoErr  \n'
#                 'engine warning lamp \n'
#                 'comes on continually.  \n'
#                 ' \n'
#                 '“YES”  \n'
#                 '**** code is indicated \n'
#                 'in order of occurrence.  \n'
#                 'engine warning lamp \n'
#                 'comes on continually.  \n'
#                 'For each 2 sec., \n'
#                 'code is indicated.\n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'ENGINE \n'
#                 'RUNNING   \n'
#                 '“NO”  \n'
#                 'NoErr  \n'
#                 'engine warning lamp \n'
#                 'goes off.  \n'
#                 ' \n'
#                 '“YES”  \n'
#                 '**** code is indicated \n'
#                 'in order of occurrence.  \n'
#                 'engine warning lamp \n'
#                 'comes on continually..  \n'
#                 'For each 2 sec., \n'
#                 'code is indicated.\n'
#                 '  \n'
#                 'N O T E \n'
#                 'If press the select switch © (in the “no Err” display state) '
#                 'for 0.6 ~ 1 seconds, it is changed into the odometer mode.  \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-13 EI SYSTEM DIAGNOSIS',
#                 'SELF-DIAGNOSTIC PROCEDURES \n'
#                 'Don’t disconnect couplers from ECU, battery cable fr om '
#                 'battery, ECU ground wire harness from engine or \n'
#                 'main fuse before confirming malfunction code (self-di '
#                 'agnostic trouble code) stored in memory. the memorized \n'
#                 'malfunction code is displayed in the code form on the '
#                 'odometer screen B or by blinks signal of the engine \n'
#                 'warning lamp “  ” A. \n'
#                 ' \n'
#                 ' To check malfunction code, read SELF-DIAGNOSIS FUNC TION '
#                 '“DEALER MODE” (Refer to page [4-11~ 18]) \n'
#                 'carefully to have good understanding as to what  functions '
#                 'are available and how to use it. \n'
#                 ' \n'
#                 'Be sure to read “PRECAUTIONS for Electrical Circui t Service” '
#                 '(Refer to page [4-1]) before inspection and \n'
#                 'observe what is written there. \n'
#                 '   \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-22  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'A. ODOMETER SCREEN INDICATION \n'
#                 'Refer to page [4-11] \n'
#                 ' \n'
#                 ' \n'
#                 'B. ENGINE WARNING LAMP INDICATION \n'
#                 'Refer to page [4-13] \n'
#                 '      \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '   \n'
#                 ' \n'
#                 '    H\n'
#                 '    P  USKEY\n'
#                 ' \n'
#                 ' \n'
#                 '4-23 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'SELF-DIAGNOSIS RESET \n'
#                 'PROCEDURE',
#                 '[         0             5              0             '
#                 '5             0              5          ]  \n'
#                 'ISC Error  \n'
#                 'P0562   \n'
#                 '[         0             5          6        2            '
#                 '0             5         6       2    ]  \n'
#                 'Battery Voltage Low  \n'
#                 'P0563   \n'
#                 '[         0             5          6        3            '
#                 '0              5         6          ]  \n'
#                 'Battery Voltage High  \n'
#                 'P0601   \n'
#                 '[         0              6              0         '
#                 '1            0             6              ]  \n'
#                 'Ecu Fault  \n'
#                 'P0650   \n'
#                 '[         0              6          5             '
#                 '0                  0                    ]  \n'
#                 'Engine warning lamp Circuit Malfunction  \n'
#                 'P0850   \n'
#                 '[         0               8             5            '
#                 '0                 0                 ]  \n'
#                 'GP or clutch lever swit ch Circuit Malfunction  \n'
#                 ' \n'
#                 '    \n'
#                 ' \n'
#                 '   ※A CODE ： For Odometer screen indication \n'
#                 ' \n'
#                 '※B CODE ： For Engine warning lamp indication \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-18  \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARNING LAMP INDICATION'],
#                ['The memorized malfunction code is displayed on the odometer '
#                 'screen B or by blinks signal of the engine warning \n'
#                 'lamp “ ” A. \n'
#                 'Malfunction means that the ECU does not receive signal from '
#                 'the devices or fault signal received. \n'
#                 'These affected devices are indicated in the code form on the '
#                 'odometer screen B or displayed by blinks signal \n'
#                 'of the engine warning lamp “ ” A. \n'
#                 'A. ODOMETER SCREEN \n'
#                 'To confirm the memorized malfunction code through the '
#                 'odometer screen B. \n'
#                 '1. Remove the left side cover. \n'
#                 '2. Connect the special tool to the dealer mode coupler at the '
#                 'wiri ng harness, and the ignition switch is set to the “ON” '
#                 'position.  \n'
#                 ' Mode select switch: 09900-27000  \n'
#                 '3. Turn the special tool’s switch to the “ON” position. \n'
#                 '4. Press the select switch  C (in the odometer mode) for 5 '
#                 'seconds until  the odometer screen B is displayed \n'
#                 '[the malfunction code mode] after displaying the “SEND” '
#                 'letters for a second. \n'
#                 ' \n'
#                 'N O T E',
#                 '1. Remove the left side cover. \n'
#                 '2. Connect the special tool to the dealer mode coupler at the '
#                 'wiri ng harness, and the ignition switch is set to the “ON” '
#                 'position.  \n'
#                 ' Mode select switch: 09900-27000  \n'
#                 '3. Turn the special tool’s switch to the “ON” position. \n'
#                 '4. Press the select switch  C (in the odometer mode) for 5 '
#                 'seconds until  the odometer screen B is displayed \n'
#                 '[the malfunction code mode] after displaying the “SEND” '
#                 'letters for a second. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'This time, if not connect the special tool,  the odometer '
#                 'screen B is indicates the “CH ECK” letters. \n'
#                 'If press the select switch  C for 0.6 ~ 1 seconds, the '
#                 '“CHECK” letters disappear.  \n'
#                 ' \n'
#                 '5. The memorized malfunction code is displayed in the code '
#                 'form on the odometer screen B. \n'
#                 '6. Start the engine and repeat the above procedure. \n'
#                 '7. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 '8. If press the select switch C (in the malfunction code '
#                 'mode) for 0.6 ~ 1 seconds, [the malfunction code',
#                 '3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS \n'
#                 'P0031  [         0                  0          3    '
#                 '1            0                0            3    1   ]  \n'
#                 'NO.1 O₂S heater Circuit Low Voltage For NO.1 cylinder \n'
#                 'P0032    \n'
#                 '[         0                  0           3     2            '
#                 '0                 0           3       ]  \n'
#                 'NO.1 O₂S heater Circuit High Voltage  For NO.1 cylinder  \n'
#                 'P0037    \n'
#                 '[         0                  0           3          '
#                 '7               0                 0          ]  \n'
#                 'NO.2 O2Sheater Ci rcuit Low Voltage For NO.2 cylinder \n'
#                 'P0038',
#                 'SELF-DIAGNOSTIC PROCEDURES \n'
#                 'Don’t disconnect couplers from ECU, battery cable fr om '
#                 'battery, ECU ground wire harness from engine or \n'
#                 'main fuse before confirming malfunction code (self-di '
#                 'agnostic trouble code) stored in memory. the memorized \n'
#                 'malfunction code is displayed in the code form on the '
#                 'odometer screen B or by blinks signal of the engine \n'
#                 'warning lamp “  ” A. \n'
#                 ' \n'
#                 ' To check malfunction code, read SELF-DIAGNOSIS FUNC TION '
#                 '“DEALER MODE” (Refer to page [4-11~ 18]) \n'
#                 'carefully to have good understanding as to what  functions '
#                 'are available and how to use it. \n'
#                 ' \n'
#                 'Be sure to read “PRECAUTIONS for Electrical Circui t Service” '
#                 '(Refer to page [4-1]) before inspection and \n'
#                 'observe what is written there. \n'
#                 '   \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-22  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'A. ODOMETER SCREEN INDICATION \n'
#                 'Refer to page [4-11] \n'
#                 ' \n'
#                 ' \n'
#                 'B. ENGINE WARNING LAMP INDICATION \n'
#                 'Refer to page [4-13] \n'
#                 '      \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '   \n'
#                 ' \n'
#                 '    H\n'
#                 '    P  USKEY\n'
#                 ' \n'
#                 ' \n'
#                 '4-23 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'SELF-DIAGNOSIS RESET \n'
#                 'PROCEDURE',
#                 'If press the select switch  C for 0.6 ~ 1 seconds, the '
#                 '“CHECK” letters disappear.  \n'
#                 ' \n'
#                 '5. The memorized malfunction code is displayed in the code '
#                 'form on the odometer screen B. \n'
#                 '6. Start the engine and repeat the above procedure. \n'
#                 '7. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 '8. If press the select switch C (in the malfunction code '
#                 'mode) for 0.6 ~ 1 seconds, [the malfunction code \n'
#                 'mode] is changed into[the odometer mode]. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the odometer screen B is displayed '
#                 'the current code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-12  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '             \n'
#                 '❖ Confirm the malfunction code after turning the ignition '
#                 'switch “ON” position and starting the engine \n'
#                 'separately. \n'
#                 '❖ The dealer mode coupler of the wiring harness is located '
#                 'Left side cover. \n'
#                 '  \n'
#                 'CLASSIFICATION MALFUNCTI\n'
#                 'ON ODOMETERSCR\n'
#                 'EEN \n'
#                 'INDICATION B ENGINE \n'
#                 'WARNING LAMP \n'
#                 'INDICATION A INDICATION \n'
#                 'MODE \n'
#                 ' \n'
#                 ' \n'
#                 'IGNITION \n'
#                 'SWITCH \n'
#                 '“ON” \n'
#                 'POSTION   \n'
#                 '“NO”  \n'
#                 'NoErr  \n'
#                 'engine warning lamp',
#                 'B. ENGINE WARNING LAMP \n'
#                 'To confirm the memorized malfunction code through the engine '
#                 'warning lamp “ ”  A: \n'
#                 '1. Turn the ignition switch alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by three times. \n'
#                 ' \n'
#                 'Take special care when operating above procedure. \n'
#                 'If the ignition switch is turned alternately, “ON” and “OFF” '
#                 'position, for 2 seconds by five times, the ECU is '
#                 'initialized.\n'
#                 ' \n'
#                 '2. The memorized malfunction code is displayed with blinks '
#                 'signal of the engine warning lamp “  ” A. \n'
#                 '3. Check the malfunction code to determine the malfunction '
#                 'part. \n'
#                 ' \n'
#                 'N O T E \n'
#                 'The malfunction code of the engine warning lamp “ ” A is '
#                 'displayed both the current code(s) and history code(s).  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'MALFUNCTION ENGINE WARNING LAMP INDICATION A  \n'
#                 '“NO” Engine warning lamp comes continually \n'
#                 '“YES” Malfunction code is displayed by blinking signal \n'
#                 'In order of occurrence \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-14 \n'
#                 ' \n'
#                 ' \n'
#                 'A CODE B CODE \n'
#                 'MALFUNCTION PART REMARKS',
#                 'Be sure to read “PRECAUTIONS for Electrical Circui t Service” '
#                 '(Refer to page [4-1]) before inspection and \n'
#                 'observe what is written there. \n'
#                 '   \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-22  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'A. ODOMETER SCREEN INDICATION \n'
#                 'Refer to page [4-11] \n'
#                 ' \n'
#                 ' \n'
#                 'B. ENGINE WARNING LAMP INDICATION \n'
#                 'Refer to page [4-13] \n'
#                 '      \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '   \n'
#                 ' \n'
#                 '    H\n'
#                 '    P  USKEY\n'
#                 ' \n'
#                 ' \n'
#                 '4-23 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'SELF-DIAGNOSIS RESET \n'
#                 'PROCEDURE \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARMIMG LAMP  \n'
#                 '● Repair the trouble. \n'
#                 '● Start engine and wait for 20 seconds, and then ignition \n'
#                 'switch to the off and wait for 15 seconds. \n'
#                 ' \n'
#                 '● Repeat the above procedure 3times. \n'
#                 'In this case, engine warning lamp” ” goes off. \n'
#                 ' \n'
#                 'B. ODOMETER SCREEN   \n'
#                 '● After repairing the trouble, refer to page 30 [4-11 ], \n'
#                 'move\n'
#                 ' the malfunction code mode \n'
#                 '● If the odometer screen B indicates the “no Err” letters, \n'
#                 'the malfunction codes are cleared . \n'
#                 '●  Disconnect the special t ool from the dealer mode \n'
#                 'coupler at the wiring harness. \n'
#                 ' \n'
#                 ' \n'
#                 '. \n'
#                 ' \n'
#                 '   \n'
#                 ' \n'
#                 '                   \n'
#                 '    H',
#                 'Ecu Fault  \n'
#                 'P0650   \n'
#                 '[         0              6          5             '
#                 '0                  0                    ]  \n'
#                 'Engine warning lamp Circuit Malfunction  \n'
#                 'P0850   \n'
#                 '[         0               8             5            '
#                 '0                 0                 ]  \n'
#                 'GP or clutch lever swit ch Circuit Malfunction  \n'
#                 ' \n'
#                 '    \n'
#                 ' \n'
#                 '   ※A CODE ： For Odometer screen indication \n'
#                 ' \n'
#                 '※B CODE ： For Engine warning lamp indication \n'
#                 ' \n'
#                 ' EI SYSTEM DIAGNOSIS 4-18  \n'
#                 ' \n'
#                 ' \n'
#                 'A. ENGINE WARNING LAMP INDICATION  \n'
#                 'In the engine warning lamp“ ”A the malfunction code is '
#                 'displayed by blin king the signal in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 'B. ODOMETER SCREENINDICATION  \n'
#                 'In the odometer screen B, the malfunction code is indicated '
#                 'in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-19 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'EI SYSTEM TROUBLESHOOTING \n'
#                 'CUSTOMER COMPLAINT ANALYSIS \n'
#                 'Record details of the problem (failure, complaint) and how it '
#                 'occurred as described by the customer.',
#                 'A. ENGINE WARNING LAMP INDICATION  \n'
#                 'In the engine warning lamp“ ”A the malfunction code is '
#                 'displayed by blin king the signal in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 'B. ODOMETER SCREENINDICATION  \n'
#                 'In the odometer screen B, the malfunction code is indicated '
#                 'in order of occurrence. \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-19 EI SYSTEM DIAGNOSIS  \n'
#                 ' \n'
#                 'EI SYSTEM TROUBLESHOOTING \n'
#                 'CUSTOMER COMPLAINT ANALYSIS \n'
#                 'Record details of the problem (failure, complaint) and how it '
#                 'occurred as described by the customer. \n'
#                 'For this purpose, use of such an inspec tion form will '
#                 'facilitate co llecting information to the point required for '
#                 'proper \n'
#                 'analysis and diagnosis. \n'
#                 ' \n'
#                 '▣ EXAMPLE : CUSTOMER PRO BLEM INSPECTION FORM \n'
#                 'User name : Model : VIN : \n'
#                 'Date of issue : Date Reg. : Date of problem : Mileage : \n'
#                 ' \n'
#                 ' \n'
#                 'Engine warning lamp 口  \n'
#                 'Always ON 口 Sometimes ON 口 \n'
#                 'Always \n'
#                 'OFF 口  \n'
#                 'Good   \n'
#                 'condition \n'
#                 'Malfunction display / code \n'
#                 '(odometer screen) or Blinks signal ( Engine warning lamp)  \n'
#                 '口  \n'
#                 ' \n'
#                 'No code  \n'
#                 '口 \n'
#                 ' \n'
#                 'Malfunction code ( \n'
#                 ' \n'
#                 ')',
#                 'EI SYSTEM DIAGNOSIS 4-12  \n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 '             \n'
#                 '❖ Confirm the malfunction code after turning the ignition '
#                 'switch “ON” position and starting the engine \n'
#                 'separately. \n'
#                 '❖ The dealer mode coupler of the wiring harness is located '
#                 'Left side cover. \n'
#                 '  \n'
#                 'CLASSIFICATION MALFUNCTI\n'
#                 'ON ODOMETERSCR\n'
#                 'EEN \n'
#                 'INDICATION B ENGINE \n'
#                 'WARNING LAMP \n'
#                 'INDICATION A INDICATION \n'
#                 'MODE \n'
#                 ' \n'
#                 ' \n'
#                 'IGNITION \n'
#                 'SWITCH \n'
#                 '“ON” \n'
#                 'POSTION   \n'
#                 '“NO”  \n'
#                 'NoErr  \n'
#                 'engine warning lamp \n'
#                 'comes on continually.  \n'
#                 ' \n'
#                 '“YES”  \n'
#                 '**** code is indicated \n'
#                 'in order of occurrence.  \n'
#                 'engine warning lamp \n'
#                 'comes on continually.  \n'
#                 'For each 2 sec., \n'
#                 'code is indicated.\n'
#                 ' \n'
#                 ' \n'
#                 ' \n'
#                 'ENGINE \n'
#                 'RUNNING   \n'
#                 '“NO”  \n'
#                 'NoErr  \n'
#                 'engine warning lamp \n'
#                 'goes off.  \n'
#                 ' \n'
#                 '“YES”  \n'
#                 '**** code is indicated \n'
#                 'in order of occurrence.  \n'
#                 'engine warning lamp \n'
#                 'comes on continually..  \n'
#                 'For each 2 sec., \n'
#                 'code is indicated.\n'
#                 '  \n'
#                 'N O T E \n'
#                 'If press the select switch © (in the “no Err” display state) '
#                 'for 0.6 ~ 1 seconds, it is changed into the odometer mode.  \n'
#                 ' \n'
#                 '  \n'
#                 ' \n'
#                 ' \n'
#                 ' 4-13 EI SYSTEM DIAGNOSIS']],
#  'embeddings': None,
#  'ids': [['b93dca52-63a2-11ee-91a7-da6035817b53',
#           'b93dcaa2-63a2-11ee-91a7-da6035817b53',
#           'b93dcb4c-63a2-11ee-91a7-da6035817b53',
#           'b93dcb10-63a2-11ee-91a7-da6035817b53',
#           'b93dccaa-63a2-11ee-91a7-da6035817b53',
#           'b93dcb9c-63a2-11ee-91a7-da6035817b53',
#           'b93dc962-63a2-11ee-91a7-da6035817b53',
#           'b93dc976-63a2-11ee-91a7-da6035817b53',
#           'b93dcb42-63a2-11ee-91a7-da6035817b53',
#           'b93dca8e-63a2-11ee-91a7-da6035817b53'],
#          ['b93dcaa2-63a2-11ee-91a7-da6035817b53',
#           'b93dcb4c-63a2-11ee-91a7-da6035817b53',
#           'b93dca52-63a2-11ee-91a7-da6035817b53',
#           'b93dcb60-63a2-11ee-91a7-da6035817b53',
#           'b93dccaa-63a2-11ee-91a7-da6035817b53',
#           'b93dca8e-63a2-11ee-91a7-da6035817b53',
#           'b93dcc8c-63a2-11ee-91a7-da6035817b53',
#           'b93dca7a-63a2-11ee-91a7-da6035817b53',
#           'b93dcb9c-63a2-11ee-91a7-da6035817b53',
#           'b93dcb42-63a2-11ee-91a7-da6035817b53'],
#          ['b93dca52-63a2-11ee-91a7-da6035817b53',
#           'b93dca5c-63a2-11ee-91a7-da6035817b53',
#           'b93dcaa2-63a2-11ee-91a7-da6035817b53',
#           'b93dcb9c-63a2-11ee-91a7-da6035817b53',
#           'b93dca66-63a2-11ee-91a7-da6035817b53',
#           'b93dca8e-63a2-11ee-91a7-da6035817b53',
#           'b93dcba6-63a2-11ee-91a7-da6035817b53',
#           'b93dcb4c-63a2-11ee-91a7-da6035817b53',
#           'b93dcb60-63a2-11ee-91a7-da6035817b53',
#           'b93dca7a-63a2-11ee-91a7-da6035817b53']],
#  'metadatas': [[{'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'}],
#                [{'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'}],
#                [{'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'},
#                 {'source': './data/hyosung.txt'}]]}

# %%
from pprint import pprint

# %%
summary_of_answers = "".join(result["documents"][0])

# %%
llm = OpenAI(model_name='text-davinci-003', temperature=0, openai_api_key=OPENAI_API_KEY)
qa_chain_1 = VectorDBQA.from_chain_type(llm=llm, chain_type='stuff', vectorstore=docsearch_1)
# Out:
# /Users/adammabrouk/testocr/env/lib/python3.11/site-packages/langchain/chains/retrieval_qa/base.py:251: UserWarning: `VectorDBQA` is deprecated - please use `from langchain.chains import RetrievalQA`
#   warnings.warn(

# %%
summary_of_answers = ""
for q in QUESTIONS:
    print(q)
    answer_1 = qa_chain_1.run(q)
    summary_of_answers += "Question: " + q + "\n"
    summary_of_answers += f"{NAMES[0]} answer: " + answer_1
    print(NAMES[0], answer_1)
# Out:
# When i click on the started, i hear a sound of a spark but the moto doesn't start, what is the problem ?
# HyosungManual  It is likely that the ignition switch is not set to the "ON" position, or the ECU is not receiving a signal from the devices. It is recommended to check the ECU for any memorized malfunction codes.

# %%
encoder = tiktoken.encoding_for_model("gpt-3.5-turbo")
len(encoder.encode(summary_of_answers))
# Out:
# 80

# %%
print(summary_of_answers)
# Out:
# Question: When i click on the started, i hear a sound of a spark but the moto doesn't start, what is the problem ?
# HyosungManual answer:  It is likely that the ignition switch is not set to the "ON" position, or the ECU is not receiving a signal from the devices. It is recommended to check the ECU for any memorized malfunction codes.

# %% [markdown]
# ## Asking to compare the answers

# %%
template = """
I want you to act motor repair expert. 
I have searched the repair manual trying to answer the following questions :

{QUESTIONS}
Here is a list of answers i found in the repair manual
{summary_of_answers}
Please take into account that the answers could go out of scope, so try to stick as much as possible to the elements in the questions
Formulate for me an answer given the previous details
Your answer:
"""

prompt = PromptTemplate(
    input_variables=["QUESTIONS","summary_of_answers"],
    template=template,
)

# %%
llm = OpenAI(model_name='text-davinci-003', temperature=0, openai_api_key=OPENAI_API_KEY, request_timeout=60)
chain = LLMChain(llm=llm, prompt=prompt)

# %%
answer = chain.run({'summary_of_answers': summary_of_answers, 'QUESTIONS': QUESTIONS})

# %%
print(answer)
# Out:
# It sounds like the ignition switch may not be set to the "ON" position, or the ECU is not receiving a signal from the devices. To diagnose the issue, it is recommended to check the ECU for any memorized malfunction codes.

# %%
qa_chain_1.vectorstore.persist()
